# %% [markdown]
# <a href="https://colab.research.google.com/github/gitflai/exerciciosPython/blob/main/Curso_Python_para_Data_Science_Parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ✨ **Aula 11 - Conhecendo mais o Google Colab**

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## ◾ **O que o Google Colab Oferece?**

# %% [markdown]
# ## ◾ **Comandos "Mágicos"**
# %magic   %hist   %pwd   %reset   %who   %whos   %timeit
#
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %%
# %magic

# %%
# %hist
# Out:
# a = 2
# b = True
# a = 2
# b = True
# # load an example dataset
# from vega_datasets import data
# cars = data.cars()
#
# # plot the dataset, referencing dataframe column names
# import altair as alt
# alt.Chart(cars).mark_bar().encode(
#   x=alt.X('Miles_per_Gallon', bin=True),
#   y='count()',
# )
# a
# b
# cars
# cars
# data
# %magic
# %hist

# %%
# %pwd
# Out:
# '/content'

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
a = 1
b = True
c = 'Ricardo'

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     1
# b          bool    True
# c          str     Ricardo

# %%
# %%timeit 

[i**2 for i in range(1000)]
# Out:
# 1000 loops, best of 5: 225 µs per loop

# %% [markdown]
# ## ◾ **Conexão com o GitHub**
